# %% [markdown]
# # Esercizi Vacanze di Natale 2025 – Programmazione in Python (3T)

# %% [markdown]
# ## Esercizio 1
#
# ### Testo
#
# Chiedi all’utente due numeri reali a e b e stampa la distanza tra i due numeri sulla retta reale. La distanza
# tra due numeri è sempre un valore non negativo ed è data dalla differenza in valore assoluto.
#
# ESEMPIO: a = −3.5, b = 2  distanza = | − 3.5 − 2| = 5.5
#
#
# ### Spiegazione
#
# Qui prendiamo **due numeri reali** `a` e `b` e vogliamo capire “**quanto sono lontani**”.
#
# - Se `a` è più piccolo di `b`, la differenza `b - a` è positiva.
# - Se `a` è più grande di `b`, la differenza `a - b` è positiva.
# - In generale, la distanza è il **valore assoluto** della differenza: `|a - b|`.
#
# Esempio veloce:
# - tra 10 e 7 la distanza è 3
# - tra 7 e 10 la distanza è sempre 3 (quindi serve un modo per renderla non negativa)

# %%
# Esercizio 1 - Distanza tra due numeri reali
# Possibile utilizzo di abs()

# %% [markdown]
# ## Esercizio 2
#
# ### Testo
#
# Chiedi all’utente tre numeri reali e stabilisci se possono rappresentare i lati di un triangolo. Tre numeri
# possono essere lati di un triangolo se ciascuno è minore della somma degli altri due.
#
# ESEMPIO: 3, 4, 5 → si (perché 3 < 4 + 5, 4 < 3 + 5, 5 < 3 + 4)
# 1, 2, 3 → no (perché 3 = 1 + 2)
#
#
# ### Spiegazione
#
# Qui utilizziamo la **condizione di esistenza del triangolo**:
#
# Se i lati sono `a`, `b`, `c`, allora devono valere tutte e tre:
# - `a < b + c`
# - `b < a + c`
# - `c < a + b`
#
# Se anche solo una non è vera, non possiamo formare un triangolo.
#
# Esempio:
# - 3, 4, 5 funziona (è il classico triangolo “ben formato”)
# - 1, 2, 3 non funziona perché il lato più grande “schiaccia” gli altri due: 3 non è minore di 1+2

# %%
# Esercizio 2 - Lati di un triangolo

# %% [markdown]
# ## Esercizio 3
#
# ### Testo
#
# Chiedi all’utente un numero reale x e un intero positivo n e calcola la media dei primi n multipli di x. I
# multipli sono: x, 2x, 3x, . . . , nx.
#
# ESEMPIO: x = 2, n = 4
# multipli: 2, 4, 6, 8
# media = (2+4+6+8) / 4 = 5
#
#
# ### Spiegazione
#
# Prendiamo un reale `x` e un intero `n`.
#
# - I multipli sono: `1*x`, `2*x`, `3*x`, ... `n*x`
# - Per fare la media, ci serve:
#   1) sommare tutti questi multipli
#   2) dividere la somma per `n`
#
# Conviene usare un ciclo (ad esempio `for`) con un contatore `i` che va da 1 a n.

# %%
# Esercizio 3 - Media dei primi n multipli di x

# %% [markdown]
# ## Esercizio 4
#
# ### Testo
#
# Chiedi all’utente un intero n e stampa tutti i numeri compresi tra 1 e n che sono multipli di 4 ma non
# multipli di 6. Un numero è multiplo di un altro se il resto della divisione è zero.
#
# ESEMPIO: n = 30
# numeri richiesti: 4, 8, 12, 16, 20, 28
# (il numero 24 è escluso perché è multiplo anche di 6)
#
#
# ### Spiegazione
#
# Qui scorriamo tutti i numeri da 1 a `n` e selezioniamo quelli che rispettano **due condizioni**:
#
# - multiplo di 4  → `numero % 4 == 0`
# - NON multiplo di 6 → `numero % 6 != 0`
#
# Quindi, per ogni numero:
# - se entrambe le condizioni sono vere, lo stampiamo.

# %%
# Esercizio 4 - Multipli di 4 ma non di 6

# %% [markdown]
# ## Esercizio 5
#
# ### Testo
#
# Chiedi all’utente un intero positivo n e calcola la somma alternata:
#
# S = 1 − 2 + 3 − 4 + · · · ± n
#
# Il segno cambia ad ogni termine.
#
# ESEMPIO: n = 6
# S = 1 − 2 + 3 − 4 + 5 − 6 = −3
#
#
# ### Spiegazione
#
# Vogliamo sommare i numeri da 1 a `n`, ma alternando il segno:
#
# - i dispari si sommano (segno +)
# - i pari si sottraggono (segno -)
#
# Quindi per ogni `i`:
# - se `i` è pari (`i % 2 == 0`), facciamo `S = S - i`
# - altrimenti facciamo `S = S + i`

# %%
# Esercizio 5 - Somma alternata

# %% [markdown]
# ## Esercizio 6
#
# ### Testo
#
# Chiedi all’utente un intero n e un intero k e calcola quante volte compare il numero k come multiplo di
# se stesso tra 1 e n. In pratica devi contare quanti multipli di k sono minori o uguali a n.
#
# ESEMPIO: n = 25, k = 4
# multipli di 4: 4, 8, 12, 16, 20, 24
# conteggio = 6
#
#
# ### Spiegazione
#
# Stiamo contando quanti multipli di `k` stanno dentro l’intervallo 1..`n`.
#
# Un modo “da ciclo” è:
# - partiamo da `k`
# - poi `2k`, `3k`, ...
# - ci fermiamo quando superiamo `n`
# - ogni volta che troviamo un multiplo valido aumentiamo un contatore.
#
# In alternativa, a livello matematico sarebbe `n // k`, ma qui possiamo scegliere il metodo che preferiamo
# (soprattutto se vogliamo allenare i cicli).

# %%
# Esercizio 6 - Conteggio multipli di k <= n

# %% [markdown]
# ## Esercizio 7
#
# ### Testo
#
# Chiedi all’utente un numero reale x e un intero n e calcola la somma delle potenze:
#
# S = x + x^2 + x^3 + · · · + x^n
#
# La potenza indica quante volte il numero viene moltiplicato per se stesso.
#
# ESEMPIO: x = 2, n = 4
# S = 2 + 4 + 8 + 16 = 30
#
#
# ### Spiegazione
#
# Dobbiamo sommare `x^1 + x^2 + ... + x^n`.
#
# Possiamo procedere in due modi:
# 1) calcolare ogni potenza con un meccanismo di moltiplicazioni ripetute
# 2) aggiornare una variabile `potenza` passo passo:
#    - partiamo da `potenza = x` (che è x^1)
#    - poi ad ogni giro facciamo `potenza = potenza * x` (così otteniamo la successiva)
#
# In questo modo evitiamo di “ricominciare da capo” ogni volta.

# %%
# Esercizio 7 - Somma delle potenze

# %% [markdown]
# ## Esercizio 8
#
# ### Testo
#
# Chiedi all’utente due interi n e m e calcola il prodotto n·m utilizzando solo somme ripetute. Moltiplicare
# significa sommare più volte lo stesso numero.
#
# ESEMPIO: n = 7, m = 5
# 7 · 5 = 7 + 7 + 7 + 7 + 7 = 35
#
#
# ### Spiegazione
#
# Qui “simuliamo” la moltiplicazione con somme ripetute:
#
# - `n * m` significa sommare `n` per `m` volte (oppure sommare `m` per `n` volte).
# - Quindi utilizziamo un ciclo che ripete `m` volte l’operazione `somma += n`.
#
# Esempio:
# - se n = 7 e m = 5, facciamo: somma = 0, poi aggiungiamo 7 cinque volte.

# %%
# Esercizio 8 - Prodotto con somme ripetute

# %% [markdown]
# ## Esercizio 9
#
# ### Testo
#
# Chiedi all’utente un intero n e determina se è un numero perfetto. Un numero è perfetto se è uguale alla
# somma dei suoi divisori positivi, escluso se stesso.
#
# ESEMPIO: n = 6
# divisori: 1, 2, 3
# 1 + 2 + 3 = 6 → perfetto
# n = 12 → non perfetto
#
#
# ### Spiegazione
#
# Dobbiamo trovare i **divisori positivi** di `n` (escludendo `n`) e sommarli.
#
# Un numero `d` è divisore di `n` se:
# - `n % d == 0`
#
# Quindi:
# - scorriamo `d` da 1 a `n-1`
# - se `d` divide `n`, lo aggiungiamo a `somma_divisori`
# - alla fine confrontiamo `somma_divisori` con `n`

# %%
# Esercizio 9 - Numero perfetto

# %% [markdown]
# ## Esercizio 10
#
# ### Testo
#
# Chiedi all’utente un intero N e successivamente il programma chiederà all’utente di inserire altri N numeri
# reali. Al termine stampare il valore massimo, il valore minimo e la loro differenza tra gli N numeri reali
# inseriti.
#
# ESEMPIO: N = 4
# numeri inseriti: 2, −1, 5, 3
# max = 5, min = −1
# differenza = 5 − (−1) = 6
#
#
# ### Spiegazione
#
# Qui inseriamo `N` numeri reali e vogliamo:
# - massimo
# - minimo
# - differenza `max - min`
#
# Conviene quindi eseguire le seguenti operazioni:
# 1) leggere il **primo** numero e usarlo come valore iniziale sia per `minimo` sia per `massimo`
# 2) poi per i successivi `N-1` numeri:
#    - se il nuovo numero è più grande del massimo, aggiorniamo `massimo`
#    - se il nuovo numero è più piccolo del minimo, aggiorniamo `minimo`
# Alla fine calcoliamo la differenza.

# %%
# Esercizio 10 - Max, min e differenza su N numeri reali
