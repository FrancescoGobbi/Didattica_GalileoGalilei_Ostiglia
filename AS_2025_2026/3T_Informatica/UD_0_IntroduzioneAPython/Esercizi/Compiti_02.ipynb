# %% [markdown]
# # Compiti 02 - Condizioni in Python
#
# **Francesco Gobbi**
# *I.I.S.S. Galileo Galilei, Ostiglia*
#
# Documentazione ufficiale Python: https://docs.python.org/3/

# %%
# Esercizio 1:
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve verificare se il numero è positivo, negativo o zero
# e stampare un messaggio appropriato.

# TO DO...

# %%
# Esercizio 2:
# Scrivere un programma in Python che prenda in input 4 numeri interi.
# Il programma deve trovare e stampare il massimo e il minimo tra i numeri inseriti.

# TO DO...

# %%
# esercizio 3:
# Scrivere un programma in Python che prenda in input 5 numeri.
# Eserguire la somma e la media dei numeri inseriti e stampare i risultati.
# Successivamente, se la media è maggiore di 50, stampare "Media alta", altrimenti stampare "Media bassa".

# TO DO...

# %%
# esercizio 4:
# Scrivere un programma in Python che, ipotizzando di prendere in input un voto scolastico in decimi,::
# stampi un giudizio secondo questa tabella:
# 0–4: "Gravemente insufficiente"
# 5: "Insufficiente"
# 6: "Sufficiente"
# 7: "Discreto"
# 8: "Buono"
# 9–10: "Ottimo"

# TO DO...
