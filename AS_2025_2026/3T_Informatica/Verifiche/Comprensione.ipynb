# %%
import sys
a=18
b=2.0
c="ciao"
z=c 
w=c
x=a
y=b
x=x+2
y=y*2
x=x**2
b=b+1
b=b**3
a=a+x
y=y+1
b=b-y

print("a:",a,type(a),id(a),sys.getsizeof(a))
print("b:",b,type(b),id(b),sys.getsizeof(b))
print("z:",z,type(z),id(z),sys.getsizeof(z))
print("w:",w,type(w),id(w),sys.getsizeof(w))

print("x:",x,type(x),id(x),sys.getsizeof(x))
print("y:",y,type(y),id(y),sys.getsizeof(y))
print("c:",c,type(c),id(c),sys.getsizeof(c))

# %%
import sys

a = 42
b = -3.5
c = "hello"

z = c        
w = c        

x = a
y = b

x = x - 7       
y = y / 2    
x = x / 4     
b = b * 4  
a = a - x
y = y - 0.5
b = b + y    

print(a, type(a), id(a), sys.getsizeof(a))
print(b, type(b), id(b), sys.getsizeof(b))
print(c, type(c), id(c), sys.getsizeof(c))
print(z, type(z), id(z), sys.getsizeof(z))
print(w, type(w), id(w), sys.getsizeof(w))
print(x, type(x), id(x), sys.getsizeof(x))
print(y, type(y), id(y), sys.getsizeof(y))
# Out:
# 33.25 <class 'float'> 4406487056 24
# -16.25 <class 'float'> 4410818864 24
# hello <class 'str'> 4407225264 46
# hello <class 'str'> 4407225264 46
# hello <class 'str'> 4407225264 46
# 8.75 <class 'float'> 4406486640 24
# -2.25 <class 'float'> 4410834544 24
