# %% [markdown]
# # Array in Python - Esercizi
#
# **Francesco Gobbi**
# *I.I.S.S. Galileo Galilei, Ostiglia*
#
# Documentazione ufficiale Python: https://docs.python.org/3/

# %%
# ESERCIZIO 1

# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve calcolare la somma e la media dei numeri inseriti e stamparli a video.

# ESEMPIO:
# Se n = 4 e i numeri inseriti sono 10, 20, 30, 40
# La somma è 100 e la media è 25.0

# TO DO...

# %%
# ESERCIZIO 2

# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Ordinare l'array in ordine decrescente utilizzando l'algoritmo di ordinamento.

# ESEMPIO:
# Se n = 5 e i numeri inseriti sono: 12, 7, 22, 5, 15
# Il programma deve stampare:
# Array ordinato in ordine decrescente: [22, 15, 12, 7, 5]

# TO DO...

# %%
# ESERCIZIO 3

# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Successivamente il programma deve rimuovere tutti i numeri duplicati dall'array e stampare l'array risultante senza duplicati.

# ESEMPIO:
# Se n = 7 e i numeri inseriti sono: 10, 20, 10, 30, 20, 40, 50
# Il programma deve stampare:
# Array senza duplicati: [10, 20, 30, 40, 50]

# TO DO...
