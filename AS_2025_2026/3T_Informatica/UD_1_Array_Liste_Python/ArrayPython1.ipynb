# %% [markdown]
# # Array in Python - Esercizi
#
# **Francesco Gobbi**
# *I.I.S.S. Galileo Galilei, Ostiglia*
#
# Documentazione ufficiale Python: https://docs.python.org/3/

# %%
# ESERCIZIO 1

# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve trovare e stampare il valore massimo e minimo presente nell'array.

# ESEMPIO:
# Se n = 5 e i numeri inseriti sono: 12, 7, 22, 5, 15
# Il programma deve stampare:
# Valore massimo: 22
# Valore minimo: 5

# TO DO...

# %%
# ESERCIZIO 2
# Scrivere un programma in Python che prenda in input un numero intero n ed un intero m.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve calcolare e stampare la somma e la media dei numeri maggiori di m presenti nell'array.

# ESEMPIO:
# Se n = 6, m = 10 e i numeri inseriti sono: 8, 15, 22, 5, 10, 30
# Il programma deve stampare:
# Somma dei numeri maggiori di 10: 67
# Media dei numeri maggiori di 10: 22.33  

# TO DO...

# %%
# ESERCIZIO 3
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve creare un nuovo array contenente l'array al contrario (inversa).

# ESEMPIO:
# Se n = 4 e i numeri inseriti sono: 10, 20, 30, 40
# Il programma deve stampare:
# Array originale: [10, 20, 30, 40]
# Array inverso: [40, 30, 20, 10]

# TO DO...

# %%
# ESECIZIO 4
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve rimuovere tutti i numeri pari dall'array e stampare l'array risultante.

# ESEMPIO:
# Se n = 5 e i numeri inseriti sono: 12, 7, 22, 5, 15
# Il programma deve stampare:
# Array dopo la rimozione dei numeri pari: [7, 5, 15]

# TO DO...

# %%
# ESERCIZIO 5
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve contare e stampare quanti numeri primi sono presenti nell'array.

# ESEMPIO:
# Se n = 6 e i numeri inseriti sono: 8, 15, 7, 5, 10, 13
# Il programma deve stampare:
# Numero di numeri primi nell'array: 3 

# TO DO...

# %%
# ESERCIZIO 6
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve ordinare l'array in ordine crescente e stampare l'array ordinato.

# ESEMPIO:
# Se n = 5 e i numeri inseriti sono: 12, 7, 22, 5, 15
# Il programma deve stampare:
# Array ordinato in ordine crescente: [5, 7, 12, 15, 22]

# TO DO...

# %%
# ESERCIZIO 7
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve trovare e stampare il secondo valore massimo presente nell'array.

# ESEMPIO:
# Se n = 5 e i numeri inseriti sono: 12, 7, 22, 5, 15
# Il programma deve stampare:
# Secondo valore massimo: 15

# TO DO...

# %%
# ESERCIZIO 8
# Scrivere un programma in Python che prenda in input un numero intero n.
# Il programma deve chiedere in input n numeri interi ed inserirli in un array.
# Il programma deve calcolare e stampare la somma dei numeri in posizioni pari dell'array.

# ESEMPIO:
# Se n = 6 e i numeri inseriti sono: 8, 15, 22, 5, 10, 30
# Il programma deve stampare:
# Somma dei numeri in posizioni pari: 40  (8 + 22 + 10)

# TO DO...
